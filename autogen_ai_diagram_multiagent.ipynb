# %%
# !pip install -q autogen-agentchat[gemini,retrievechat,lmm]~=0.2 flaml[automl] diagrams
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.0/382.0 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 45.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 16.6 MB/s eta 0:00:00
# ...

# %%
# pip install -q autogen-agentchat~=0.2 diagrams
# !pip install -q gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.5 MB/s eta 0:00:00

# %%
# pip install -q autogen-agentchat[retrievechat]~=0.2 flaml[automl]

# %%
# !pip install -q openinference-instrumentation-openai arize-phoenix-otel arize-phoenix
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.2/203.2 kB 10.8 MB/s eta 0:00:00
# ...

# %%
# import agentops
# agentops.init("409c1b2b-48b3-4a1a-a8d6-53f8414673e4")

# %%
# agentops.start_session()

# %%
import io
import json
config=[


              {
        "model": "gpt-4o",
        "api_key": "d96984c9484244588895eee6a62c3d80",
        "base_url": "https://mycapgopaig.openai.azure.com/",
        "api_type": "azure",
        "api_version": "2024-06-01"
    }
]
with io.open("OAI_CONFIG_LIST","w",encoding="utf-8")as f1:
            f1.write(json.dumps(config))
            f1.close()

# %%
from IPython.display import Image, display

import autogen
from autogen.coding import LocalCommandLineCodeExecutor
# When using a single openai endpoint, you can use the following:
# config_list = [{"model": "gpt-4o", "api_key": os.getenv("OPENAI_API_KEY")}]

# %%
config_list = autogen.config_list_from_json("OAI_CONFIG_LIST")
config_list
# Out:
# [{'model': 'gpt-4o',
#   'api_key': 'd96984c9484244588895eee6a62c3d80',
#   'base_url': 'https://mycapgopaig.openai.azure.com/',
#   'api_type': 'azure',
#   'api_version': '2024-06-01'}]

# %%
from openinference.instrumentation.openai import OpenAIInstrumentor

import phoenix as px
from phoenix.otel import register

px.launch_app()
tracer_provider = register()
monior=OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/server.py", line 65, in run
#     return asyncio.run(self.serve(sockets=sockets))
#   File "/usr/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "uvloop/loop.pyx", line 1518, in uvloop.loop.Loop.run_until_complete
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/server.py", line 69, in serve
#     await self._serve(sockets)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/server.py", line 76, in _serve
#     config.load()
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/config.py", line 426, in load
#     ws_protocol_class = import_from_string(WS_PROTOCOLS[self.ws])
# ...

# %%
from autogen import ConversableAgent
import autogen
import json


agent = ConversableAgent(
    name="My Agent",
    llm_config = {"config_list" : config_list},
    code_execution_config = False,
    human_input_mode = "NEVER",
    function_map = None
)

reply = agent.generate_reply(messages=[{"role": "user", "content": "Tell me a  joke."}])
print(reply)
# Out:
# Sure, here's one for you:
#
# Why don't scientists trust atoms?
#
# Because they make up everything!

# %%
import json
import os

import chromadb

import autogen
from autogen import AssistantAgent
from autogen.agentchat.contrib.retrieve_user_proxy_agent import RetrieveUserProxyAgent

# Accepted file formats for that can be stored in
# a vector database instance
from autogen.retrieve_utils import TEXT_FORMATS

# %%
config_list = autogen.config_list_from_json("OAI_CONFIG_LIST")

assert len(config_list) > 0
print("models to use: ", [config_list[i]["model"] for i in range(len(config_list))])
# Out:
# models to use:  ['gpt-4o']

# %%
assistant = autogen.AssistantAgent(
    name="assistant_agent",
    llm_config={
        "cache_seed": 41,  # seed for caching and reproducibility
        "config_list": config_list,  # a list of OpenAI API configurations
        "temperature": 0,  # temperature for sampling
    },  # configuration for autogen's enhanced inference API which is compatible with OpenAI API
)

# %%
ragproxyagent = RetrieveUserProxyAgent(
    name="ragproxyagent",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=3,
    retrieve_config={
        "task": "code",
        "docs_path": [
            "https://diagrams.mingrammer.com/docs/getting-started/examples",
            "https://diagrams.mingrammer.com/docs/guides/diagram",
            "https://diagrams.mingrammer.com/docs/guides/node",
            "https://diagrams.mingrammer.com/docs/guides/cluster",
            "https://diagrams.mingrammer.com/docs/guides/edge",
            "https://gist.githubusercontent.com/Praveen-Babu-techie/741eba2927f28e63bdc851bb946536d7/raw/a3bada5c34357489ac5fe9a3d3a2731e2243ba49/azure-diagram.txt",

        ],
        "chunk_token_size": 2000,
        "model": config_list[0]["model"],
        "vector_db": "chroma",
        "overwrite": True,  # Changed to True to ensure a new collection is created
        "get_or_create": True,
    },
    # code_execution_config=False
     is_termination_msg=lambda x: x.get("content", "").rstrip().endswith("TERMINATE"),
     code_execution_config={
        # the executor to run the generated code
        "executor": LocalCommandLineCodeExecutor(work_dir="coding"),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
# reset the assistant. Always reset the assistant before starting a new conversation.
import os,io,glob

assistant.reset()
# cwd=os.getcwd()
cwd=os.getcwd()+"/coding"
files=glob.glob(cwd+"/*.png")
for file in files:
      os.remove(file)

def clear_assistant():
  assistant.reset()
  # cwd=os.getcwd()
  cwd=os.getcwd()+"/coding"
  files=glob.glob(cwd+"/*.png")
  for file in files:
        os.remove(file)

# %%
# # given a problem, we use the ragproxyagent to generate a prompt to be sent to the assistant as the initial message.
# # the assistant receives the message and generates a response. The response will be sent back to the ragproxyagent for processing.
# # The conversation continues until the termination condition is met, in RetrieveChat, the termination condition when no human-in-loop is no code block detected.
# # With human-in-loop, the conversation will continue until the user says "exit".
chat_result = ragproxyagent.initiate_chat(
    assistant, message=ragproxyagent.message_generator, problem=code_problem, search_string="diagrams"
)
# Out:
# Trying to create collection.
# 2024-11-12 06:42:52,994 - autogen.agentchat.contrib.retrieve_user_proxy_agent - INFO - Found 8 chunks.
# 2024-11-12 06:42:53,010 - autogen.agentchat.contrib.vectordb.chromadb - INFO - No content embedding is provided. Will use the VectorDB's embedding function to generate the content embedding.
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 20 is greater than number of elements in index 8, updating n_results = 8
# VectorDB returns doc_ids:  [['be0bc72a', 'e2b62bc5', 'a85460cb', '64517d17', '56f1c064', 'da58c175', '1a519be6', 'cf0e7071']]
# Adding content of doc be0bc72a to context.
# Adding content of doc e2b62bc5 to context.
# Adding content of doc a85460cb to context.
# Adding content of doc 64517d17 to context.
# Adding content of doc 56f1c064 to context.
# ragproxyagent (to assistant_agent):
#
# You're a retrieve augmented coding assistant. You answer user's questions based on your own knowledge and the
# ...

# %%
# # cwd=os.getcwd()
# # files=glob.glob(cwd+"/*.png")
# # for file in files:
# #       os.remove(file)
from pprint import pprint
verbose_str="*"*42+"AGENT EXECUTION "+"*"*42+"\n"
for i in chat_result.chat_history:


  verbose_str+="-"*100+"\n"
  verbose_str+="ROLE "+i["role"].upper()+"\n"

  verbose_str+="-"*100+"\n"
  verbose_str+="NAME "+i["name"].upper()+"\n"

  verbose_str+="-"*100+"\n"

  verbose_str+="CONTENT "+i["content"]+"\n"
  # print(i["content"])
  # if isinstance(i, dict):
  #   for key, value in i.items():

  #     if(key=='content'):
  #       pass
  #     else:
  #       print(key.upper()+" "+value.upper())

  #     if(key=='content'):
  #       print(value)
  #     print("-"*100)


print(verbose_str)
# Out:
# ******************************************AGENT EXECUTION ******************************************
# ----------------------------------------------------------------------------------------------------
# ROLE ASSISTANT
# ----------------------------------------------------------------------------------------------------
# NAME RAGPROXYAGENT
# ----------------------------------------------------------------------------------------------------
# CONTENT You're a retrieve augmented coding assistant. You answer user's questions based on your own knowledge and the
# context provided by the user.
# If you can't answer the question with or without the current context, you should reply exactly `UPDATE CONTEXT`.
# For code generation, you must obey the following rules:
# Rule 1. You MUST NOT install any packages because all the packages needed are already installed.
# Rule 2. You must follow the formats below to write your code:
# ```language
# # your code
# ```
#
# ...

# %%
chat_result.chat_history[1]
# Out:
# {'content': 'To create a design diagram for Azure Function with blob storage trigger and another Azure Function with queues storage trigger, both writing data to CosmosDb using the Python diagrams module, follow these steps:\n\n1. Create a Python script that uses the diagrams module to generate the diagram.\n2. Execute the script to generate the diagram.\n\nHere is the complete Python script:\n\n```python\n# filename: azure_diagram.py\n\nfrom diagrams import Diagram, Cluster\nfrom diagrams.azure.compute import FunctionApps\nfrom diagrams.azure.database import BlobStorage, QueuesStorage, CosmosDb\n\nwith Diagram("Azure Functions with Triggers and CosmosDb", show=True):\n    blob_storage = BlobStorage("Blob Storage")\n    queue_storage = QueuesStorage("Queue Storage")\n    cosmos_db = CosmosDb("CosmosDb")\n\n    with Cluster("Azure Functions"):\n        function_blob_trigger = FunctionApps("Function with Blob Trigger")\n        function_queue_trigger = FunctionApps("Function with Queue
# ...

# %%
# # prompt: in a list of dictionary print all the key value pairs

# for i in chat_result.chat_history:
#   if isinstance(i, dict):
#     for key, value in i.items():
#       print(f"Key: {key}, Value: {value}")

# %%
def handle_design_query(user_input):
  code_problem = f"{user_input} write the script using python diagrams module, with direction as LR in a separate file and execute the script, \n Use Custom logos wherever needed \n At the end of the script have a print statement the Script executed scuccessfully "
  # print(code_problem)
  chat_result = ragproxyagent.initiate_chat(
      assistant, message=ragproxyagent.message_generator, problem=code_problem, search_string="diagrams"
  )

  verbose_str="*"*20+"AGENT EXECUTION "+"*"*20+"\n"
  img_name=""
  cwd=os.getcwd()+"/coding"
  files=glob.glob(cwd+"/*.png")
  for file in files:
        # img_name=file.split("/")[-1]
        img_name=file
        break



  for i in chat_result.chat_history:


    verbose_str+="-"*100+"\n"
    verbose_str+="ROLE "+i["role"].upper()+"\n"

    verbose_str+="-"*100+"\n"
    verbose_str+="NAME "+i["name"].upper()+"\n"

    verbose_str+="-"*100+"\n"

    verbose_str+="CONTENT "+i["content"]+"\n"
  return verbose_str,img_name

# %%
prompt="""A Gen AI Based RAG application that is hosted on VMScaleSets as an App Server orchestrator,
The app server is connected with Azure Cognitive services with label as Azure OpenAi gpt-4o LLM,
The app server is also connected with Azure AI search service which is indexed with data sources like SQL Databases, CosmosDB and Documents/Files
User asks user Queries/Messages and communicates with the application with the help of Azure App Service Mobile which acts as Mobile App or User Interface

"""

##USE THIS PROMPT - RAG PROMPT

v_data,des_image=handle_design_query(prompt)
# Out:
# Trying to create collection.
# 2024-11-12 06:55:30,660 - autogen.agentchat.contrib.retrieve_user_proxy_agent - INFO - Found 8 chunks.
# 2024-11-12 06:55:30,668 - autogen.agentchat.contrib.vectordb.chromadb - INFO - No content embedding is provided. Will use the VectorDB's embedding function to generate the content embedding.
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 20 is greater than number of elements in index 8, updating n_results = 8
# VectorDB returns doc_ids:  [['e2b62bc5', 'be0bc72a', 'a85460cb', '56f1c064', 'da58c175', '64517d17', '1a519be6', 'cf0e7071']]
# Adding content of doc e2b62bc5 to context.
# Adding content of doc be0bc72a to context.
# Adding content of doc a85460cb to context.
# Adding content of doc 56f1c064 to context.
# ragproxyagent (to assistant_agent):
#
# You're a retrieve augmented coding assistant. You answer user's questions based on your own knowledge and the
# context provided by the user.
# ...

# %%
des_image
# Out:
# '/content/coding/azure_app_service_workflow.png'

# %%
img_name=""
cwd=os.getcwd()+"/coding"
files=glob.glob(cwd+"/*.png")
for file in files:
      # img_name=file.split("/")[-1]
      img_name=file
      print(file)


      break
# Out:
# /content/coding/azure_app_service_flow.png

# %%
from IPython.display import Image, display
Image(filename=str(img_name))

# %%
cap_img_url="https://download.logo.wine/logo/Capgemini/Capgemini-Logo.wine.png"

# %%
import gradio as gr
from PIL import Image

# Function to fetch or generate image and text based on input
def display_content(text_input):
    clear_assistant()
    v_data, image_url = handle_design_query(text_input)
    return [gr.update(visible=True, value=v_data),
            gr.update(visible=True, value=image_url)]

# Create the Gradio interface with conditional visibility
with gr.Blocks() as iface:

    gr.Markdown("# Design Diagram Generator")
    # gr.Markdown("Enter your prompt with corresponding services and flows.")

    with gr.Row():
        # Left column for all text elements
        with gr.Column(scale=1):
            input_text = gr.Textbox(
                label="Enter your prompt with corresponding services and flows.",
                placeholder="Type here...",
                lines=3,
                max_lines=40
            )
            output_text = gr.Textbox(
                label="Agent Verbose",
                lines=5,
                interactive=False,
                visible=False  # Initially hidden
            )
            submit_btn = gr.Button("Generate")

        # Right column for image
        with gr.Column(scale=1):
            output_image = gr.Image(
                label="Generated Design Image",
                type="filepath",
                visible=False  # Initially hidden
            )

    # Connect the components
    submit_btn.click(
        fn=display_content,
        inputs=input_text,
        outputs=[output_text, output_image]
    )

# Launch the app
iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e178ff49414c1aaf73.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e178ff49414c1aaf73.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# from diagrams.custom import Custom
# from diagrams import Diagram, Cluster
# from urllib.request import urlretrieve
# with Diagram( show=True) as diag:

#   """CHANGE THE LABEL PARAMETER FOR CUSTOM LOGOS AS PER USER INPUT"""

#   """USE THE BELOW CODE SNIPPET FOR AZURE AI SEARCH ICON"""
#   azure_ai_search_url="https://azure.microsoft.com/svghandler/search/?width=600&height=315"
#   azure_ai_search_icon = "ai-search.png"
#   urlretrieve(azure_ai_search_url, azure_ai_search_icon)
#   azure_ai_search = Custom(label="Azure AI Search",icon_path= azure_ai_search_icon)


#   """USE THE BELOW CODE SNIPPET FOR AZURE AI SEARCH ICON"""
#   azure_ai_studio_url="https://azure.microsoft.com/svghandler/ai-studio/?width=600&height=315"
#   azure_ai_studio_icon = "ai-studio.png"
#   urlretrieve(azure_ai_studio_url, azure_ai_studio_icon)
#   azure_ai_studio = Custom(label="Azure AI Studio",icon_path= azure_ai_studio_icon)


#   """USE THE BELOW CODE SNIPPET FOR FILES AND DOCUMENTS ICON"""
#   files_url="https://cdn-icons-png.flaticon.com/512/5415/5415403.png"
#   files_icon = "files.png"
#   urlretrieve(files_url, files_icon)
#   files = Custom(label="Files", icon_path=files_icon)

#   """USE THE BELOW CODE SNIPPET FOR TEXT, CHAT AND USER MESSAGE """
#   message_url="https://icons-for-free.com/iff/png/512/chat+icon-1320184411998302345.png"
#   message_icon = "message.png"
#   urlretrieve(message_url, message_icon)
#   message = Custom(label="User Message",icon_path= message_icon)






#   message>>azure_ai_search>>azure_ai_studio>>files




# diag
